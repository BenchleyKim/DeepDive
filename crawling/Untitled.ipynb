# %%
from selenium import webdriver as wd
from bs4 import BeautifulSoup
import time
import pandas as pd 


driver = wd.Chrome(executable_path = "chromedriver.exe")
url = "https://www.youtube.com/watch?v=UREV2qfjNak"
driver.get(url)

last_page_height = driver.execute_script("return document.documentElement.scrollHeight")

while True :
    driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
    time.sleep(3.0)
    new_page_height = driver.execute_script("return document.documentElement.scrollHeight")
    
    if new_page_height == last_page_height :
        break
    last_page_height = new_page_height

html_source = driver.page_source


soup = BeautifulSoup(html_source, "lxml")
youtube_user_IDs = soup.select('div#header-author > h3 > a#author-text > span') 
youtube_comments = soup.select('yt-formatted-string#content-text')
print(youtube_user_IDs)
print(youtube_comments)

str_youtube_userIDs = [] 
str_youtube_comments = [] 
for i in range(len(youtube_user_IDs)): 
    str_tmp = str(youtube_user_IDs[i].text) # print(str_tmp) 
    str_tmp = str_tmp.replace('\n', '') 
    str_tmp = str_tmp.replace('\t', '') 
    str_tmp = str_tmp.replace('                ','') 
    str_youtube_userIDs.append(str_tmp) 
    print(str_tmp)
    str_tmp = str(youtube_comments[i].text) 
    str_tmp = str_tmp.replace('\n', '') 
    str_tmp = str_tmp.replace('\t', '') 
    str_tmp = str_tmp.replace('                ', '') 
    str_youtube_comments.append(str_tmp)
    print(str_tmp)
pd_data = {"ID":str_youtube_userIDs, "Comment":str_youtube_comments} 
youtube_pd = pd.DataFrame(pd_data)
youtube_pd.to_csv('comment_data.csv', encoding = 'utf-8-sig')
driver.close()
# Out:
# [<span class="channel-owner style-scope ytd-comment-renderer">
#               문복희 Eat with Boki
#             </span>, <span class="style-scope ytd-comment-renderer">
#               RED ASMR
#             </span>, <span class="style-scope ytd-comment-renderer">
#               chanhee_cutie
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Ju Liang
#             </span>, <span class="style-scope ytd-comment-renderer">
#               ASMR Fresh
#             </span>, <span class="style-scope ytd-comment-renderer">
#               BTS ARMY SANIA
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Mrs Mini Purple
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Genevieve Bogawit
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Hippo ASMR 입큰하마
#             </span>, <span class="style-scope ytd-comment-renderer">
#               unknown
#             </span>, <span class="style-scope ytd-comment-renderer">
#               ZUU MUKBANG
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Sunilkumar G
#             </span>, <span class="style-scope ytd-comment-renderer">
#               matsu
#             </span>, <span class="style-scope ytd-comment-renderer">
#               chanhee_cutie
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Radhika Chaweria
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Jep
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Mary Kim
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Maria Criselda Gallardo
#             </span>, <span class="style-scope ytd-comment-renderer">
#               chanhee_cutie
#             </span>, <span class="style-scope ytd-comment-renderer">
#               sena'
#             </span>, <span class="style-scope ytd-comment-renderer">
#               KuRoNuma Kaze
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Haru-ya's dan oh
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Gesture
#             </span>, <span class="style-scope ytd-comment-renderer">
#               eren's hoes
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Aigera Akman
#             </span>, <span class="style-scope ytd-comment-renderer">
#               rx
#             </span>, <span class="style-scope ytd-comment-renderer">
#               MA. ROSYLYN A3 CUIZON
#             </span>, <span class="style-scope ytd-comment-renderer">
#               afsheen kaka khel
#             </span>, <span class="style-scope ytd-comment-renderer">
#               andrew pawley
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Shahaira jane Delgado
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Squisshy
#             </span>, <span class="style-scope ytd-comment-renderer">
#               francia sauceda
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Dhanvita Basavaraj
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Hart Paja
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Chris ASMR 크리스
#             </span>, <span class="style-scope ytd-comment-renderer">
#               its _sh39
#             </span>, <span class="style-scope ytd-comment-renderer">
#               ぴょん
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Michelle Angeles
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Bts love
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Chay bato
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Vanessa Muliya
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Hanna Nicole Dialimas
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Aigera Akman
#             </span>, <span class="style-scope ytd-comment-renderer">
#               NIVEDITA
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Elizabeth Belford
#             </span>, <span class="style-scope ytd-comment-renderer">
#               메이플유저
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Qian Jing
#             </span>, <span class="style-scope ytd-comment-renderer">
#               GIRÜ kitsune
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Marie Flora
#             </span>, <span class="style-scope ytd-comment-renderer">
#               KIᗰ ᑫᑌTᗩఌ
#             </span>, <span class="style-scope ytd-comment-renderer">
#               sıkıldım evde aq
#             </span>, <span class="style-scope ytd-comment-renderer">
#               This Guy Telmen
#             </span>, <span class="style-scope ytd-comment-renderer">
#               imelda ringo
#             </span>, <span class="style-scope ytd-comment-renderer">
#               POE
#             </span>, <span class="style-scope ytd-comment-renderer">
#               MilkyWay Girl
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Yağmurstudy
#             </span>, <span class="style-scope ytd-comment-renderer">
#               ᄋPhannh
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Lisa kookie
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Kim Airra Datinguinoo
#             </span>, <span class="style-scope ytd-comment-renderer">
#               ROBIN WANGY
#             </span>, <span class="style-scope ytd-comment-renderer">
#               ROZERİN ACIOĞLU
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Jas For Life
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Nabila Nirjhor
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Riya Sparkles
#             </span>, <span class="style-scope ytd-comment-renderer">
#               stressed multi
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Shariq Ahmed
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Hannah Gomez
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Azizah Mila
#             </span>, <span class="style-scope ytd-comment-renderer">
#               しゅい
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Akana Padma
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Bint Hasan
#             </span>, <span class="style-scope ytd-comment-renderer">
#               YUI LAN
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Salvador Correlo
#             </span>, <span class="style-scope ytd-comment-renderer">
#               wendy wu
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Twiceu Bang!트둥이 짱!
#             </span>, <span class="style-scope ytd-comment-renderer">
#               mamta gupta
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Yssa Rabe
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Leiy Piad
#             </span>, <span class="style-scope ytd-comment-renderer">
#               smilegorgeous
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Jonalyn Gajol
#             </span>, <span class="style-scope ytd-comment-renderer">
#               阿波野べる
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Maryam Anwar
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Natasha Belle
#             </span>, <span class="style-scope ytd-comment-renderer">
#               SSONG ASMR
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Elen Garcia
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Rushaa Noordally
#             </span>, <span class="style-scope ytd-comment-renderer">
#               little angel
#             </span>, <span class="style-scope ytd-comment-renderer">
#               A. Jasmine
#             </span>, <span class="style-scope ytd-comment-renderer">
#               にーたろーげ
#             </span>, <span class="style-scope ytd-comment-renderer">
#               sad night
#             </span>, <span class="style-scope ytd-comment-renderer">
#               ぴえん
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Kim Ji Hoon
#             </span>, <span class="style-scope ytd-comment-renderer">
#               白咲まりん
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Ishanika Taye
#             </span>, <span class="style-scope ytd-comment-renderer">
#               ᴍɪʟᴋ ɢɢᴜᴋs
#             </span>, <span class="style-scope ytd-comment-renderer">
#               ぽぺてぃ
#             </span>, <span class="style-scope ytd-comment-renderer">
#               yu - cha
#             </span>, <span class="style-scope ytd-comment-renderer">
#               tw r
#             </span>, <span class="style-scope ytd-comment-renderer">
#               desylyn gallano
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Meghna Vaddadi
#             </span>, <span class="style-scope ytd-comment-renderer">
#               海月
#             </span>, <span class="style-scope ytd-comment-renderer">
#               a k
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Fatima Khan
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Himanshu Arya
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Maria Gena Poledo-Shepherd
#             </span>, <span class="style-scope ytd-comment-renderer">
#               SSONG ASMR
#             </span>, <span class="style-scope ytd-comment-renderer">
#               TRY 808
#             </span>, <span class="style-scope ytd-comment-renderer">
#               mvaiex
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Onkaa Tau
#             </span>, <span class="style-scope ytd-comment-renderer">
#               me kim
#             </span>, <span class="style-scope ytd-comment-renderer">
#               먹방하는 똥표
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Ana Luiza Borges
#             </span>, <span class="style-scope ytd-comment-renderer">
#               chaeng. laurent
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Akshu Rane
#             </span>, <span class="style-scope ytd-comment-renderer">
#               zryan Mhamad
#             </span>, <span class="style-scope ytd-comment-renderer">
#               ちゃんま
#             </span>, <span class="style-scope ytd-comment-renderer">
#               MJ Saga
#             </span>, <span class="style-scope ytd-comment-renderer">
#               HHT HahoeTal MUKBANG ASMR
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Merlinemonroe Pacquing
#             </span>, <span class="style-scope ytd-comment-renderer">
#               peachylalalalisa
#             </span>, <span class="style-scope ytd-comment-renderer">
#               YYY
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Kaori Miyazono
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Jærëd
#             </span>, <span class="style-scope ytd-comment-renderer">
#               frzd
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Jeanny Mary
#             </span>, <span class="style-scope ytd-comment-renderer">
#               amelya deniz
#             </span>, <span class="style-scope ytd-comment-renderer">
#               海月
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Tapati Saha
#             </span>, <span class="style-scope ytd-comment-renderer">
#               hana jj
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Bts love
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Shariq Ahmed
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Annisa Islam
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Niki_Ereri
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Lorrie Lanham
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Randa Mcgahee
#             </span>, <span class="style-scope ytd-comment-renderer">
#               T M
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Roberto Avila
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Solar Moon
#             </span>, <span class="style-scope ytd-comment-renderer">
#               jaeahyun
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Maureen Grace Rabino
#             </span>, <span class="style-scope ytd-comment-renderer">
#               ほのちゃ
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Asim Aslam
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Park Jirose
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Jera Mei Legaspi
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Akshu Rane
#             </span>, <span class="style-scope ytd-comment-renderer">
#               bea비비빅
#             </span>, <span class="style-scope ytd-comment-renderer">
#               nvrk11
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Lavanya Dissanayake
#             </span>, <span class="style-scope ytd-comment-renderer">
#               5:14
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Erine Sahureka
#             </span>, <span class="style-scope ytd-comment-renderer">
#               anujin saintuya
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Epik Mooshroom Froggy
#             </span>, <span class="style-scope ytd-comment-renderer">
#               اولَيفيا 𖤍.
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Jenny Garcia
#             </span>, <span class="style-scope ytd-comment-renderer">
#               mew mew
#             </span>, <span class="style-scope ytd-comment-renderer">
#               체리쥬글래
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Yessub ASMR
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Innellson Jimmy
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Madison G
#             </span>, <span class="style-scope ytd-comment-renderer">
#               it's Itsna
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Lê Bảo Ngọc Trương
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Resmaye Yusifova
#             </span>, <span class="style-scope ytd-comment-renderer">
#               ᄒᄋᄅ
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Chelsea Shafa
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Ressa Jamelo Guadamor
#             </span>, <span class="style-scope ytd-comment-renderer">
#               김도링
#             </span>, <span class="style-scope ytd-comment-renderer">
#               joyciee
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Shhe Hd
#             </span>, <span class="style-scope ytd-comment-renderer">
#               수수수옥
#             </span>, <span class="style-scope ytd-comment-renderer">
#               ᄒᄋᄅ
#             </span>, <span class="style-scope ytd-comment-renderer">
#               잼잼
#             </span>, <span class="style-scope ytd-comment-renderer">
#               fouroverfour
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Jane Uyesato
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Hayley B
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Buki Monster
#             </span>, <span class="style-scope ytd-comment-renderer">
#               서영
#             </span>, <span class="style-scope ytd-comment-renderer">
#               성이름
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Nansbbgrand
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Farah N.S
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Semanur Erden
#             </span>, <span class="style-scope ytd-comment-renderer">
#               알람시계
#             </span>, <span class="style-scope ytd-comment-renderer">
#               kid.344
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Eman Hassoun
#             </span>, <span class="style-scope ytd-comment-renderer">
#               中尾広子
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Althea Alba
#             </span>, <span class="style-scope ytd-comment-renderer">
#               웅웅
#             </span>, <span class="style-scope ytd-comment-renderer">
#               سمسم سمسم
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Taekookies
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Sudin Aryal
#             </span>, <span class="style-scope ytd-comment-renderer">
#               BORA ASMR 보라
#             </span>, <span class="style-scope ytd-comment-renderer">
#               라라라라라라ᅡᄅ
#             </span>, <span class="style-scope ytd-comment-renderer">
#               8A_Refi
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Aesthetic Cat
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Himanshu Arya
#             </span>, <span class="style-scope ytd-comment-renderer">
#               JGEM ASMR
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Seonhui Han
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Magara Rajan R.S
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Shafrina Azzahra
#             </span>, <span class="style-scope ytd-comment-renderer">
#               三ツ石麻衣
#             </span>, <span class="style-scope ytd-comment-renderer">
#               ᄏᄏᄏ
#             </span>, <span class="style-scope ytd-comment-renderer">
#               SOOLJI술지
#             </span>, <span class="style-scope ytd-comment-renderer">
#               ayebee
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Kamai Juhanah
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Tannie
#             </span>, <span class="style-scope ytd-comment-renderer">
#               귤탱구리
#             </span>, <span class="style-scope ytd-comment-renderer">
#               J H
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Denver Estrada
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Jenifer Handog
#             </span>, <span class="style-scope ytd-comment-renderer">
#               森嶋帆高
#             </span>, <span class="style-scope ytd-comment-renderer">
#               만두볶음
#             </span>, <span class="style-scope ytd-comment-renderer">
#               SJ K
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Keizy Minette Regua
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Apgan Anggara Septiana
#             </span>, <span class="style-scope ytd-comment-renderer">
#               아에이오우
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Life Miracle Foods channel 探秘美食
#             </span>, <span class="style-scope ytd-comment-renderer">
#               김해솔
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Teacher Danna Lukman, MSE-ESOL
#             </span>, <span class="style-scope ytd-comment-renderer">
#               ama ris
#             </span>, <span class="style-scope ytd-comment-renderer">
#               예르뀨
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Jennah Lopez
#             </span>, <span class="style-scope ytd-comment-renderer">
#               준면이귀여워
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Elmar Luna
#             </span>, <span class="style-scope ytd-comment-renderer">
#               내놔냥이
#             </span>, <span class="style-scope ytd-comment-renderer">
#               농농
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Jm Oliveros
#             </span>, <span class="style-scope ytd-comment-renderer">
#               혀니현
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Sylwia Koziuk Zrodlo
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Nailaarr
#             </span>, <span class="style-scope ytd-comment-renderer">
#               길을잃었다
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Mishi
#             </span>, <span class="style-scope ytd-comment-renderer">
#               함현빈
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Xiara Manuel
#             </span>, <span class="style-scope ytd-comment-renderer">
#               sanu
#             </span>, <span class="style-scope ytd-comment-renderer">
#               ARMY YUNA
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Dede Wini
#             </span>, <span class="style-scope ytd-comment-renderer">
#               니냐뇨
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Ayano
#             </span>, <span class="style-scope ytd-comment-renderer">
#               님콩
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Aling Aling
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Jinnie캘리뽀냐이여사
#             </span>, <span class="style-scope ytd-comment-renderer">
#               뭘봐
#             </span>, <span class="style-scope ytd-comment-renderer">
#               möcä
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Selena Cole
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Cicilia Iawphniaw
#             </span>, <span class="style-scope ytd-comment-renderer">
#               21세기
#             </span>, <span class="style-scope ytd-comment-renderer">
#               whfmdk
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Adrian Morris
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Hidayat Mendoud
#             </span>, <span class="style-scope ytd-comment-renderer">
#               si-nyaa n
#             </span>, <span class="style-scope ytd-comment-renderer">
#               ESS1 M
#             </span>, <span class="style-scope ytd-comment-renderer">
#               김yoyo
#             </span>, <span class="style-scope ytd-comment-renderer">
#               혤닌
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Kids Heart Home
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Sexy Love
#             </span>, <span class="style-scope ytd-comment-renderer">
#               이규현
#             </span>, <span class="style-scope ytd-comment-renderer">
#               김혜지
#             </span>, <span class="style-scope ytd-comment-renderer">
#               z z
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Sanaz Aamina
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Houng Mary
#             </span>, <span class="style-scope ytd-comment-renderer">
#               강보람
#             </span>, <span class="style-scope ytd-comment-renderer">
#               미지
#             </span>, <span class="style-scope ytd-comment-renderer">
#               سنيوريتا سنيوريتا
#             </span>, <span class="style-scope ytd-comment-renderer">
#               its pani
#             </span>, <span class="style-scope ytd-comment-renderer">
#               행복추구자
#             </span>, <span class="style-scope ytd-comment-renderer">
#               cris isip
#             </span>, <span class="style-scope ytd-comment-renderer">
#               최은혜
#             </span>, <span class="style-scope ytd-comment-renderer">
#               angie lee
#             </span>, <span class="style-scope ytd-comment-renderer">
#               lloyd ninian
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Giatisak Lasom
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Dutt van Erbse
#             </span>, <span class="style-scope ytd-comment-renderer">
#               danse macabre
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Biyah8
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Momina Zubair
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Manisha Singh
#             </span>, <span class="style-scope ytd-comment-renderer">
#               혠타콩
#             </span>, <span class="style-scope ytd-comment-renderer">
#               언니나다섯살이야
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Frances Nicole Rabanillo
#             </span>, <span class="style-scope ytd-comment-renderer">
#               실이TV
#             </span>, <span class="style-scope ytd-comment-renderer">
#               장태주
#             </span>, <span class="style-scope ytd-comment-renderer">
#               민트맛탕
#             </span>, <span class="style-scope ytd-comment-renderer">
#               냠냠
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Josette LeNández
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Sollah Amor Lifestyle
#             </span>, <span class="style-scope ytd-comment-renderer">
#               ハーコブレイク
#             </span>, <span class="style-scope ytd-comment-renderer">
#               CK DRAMA OST WORLD
#             </span>, <span class="style-scope ytd-comment-renderer">
#               찌미콩
#             </span>, <span class="style-scope ytd-comment-renderer">
#               memzie soup
#             </span>, <span class="style-scope ytd-comment-renderer">
#               paarururu
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Vaishali Kshirsagar
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Ewura Akua
#             </span>, <span class="style-scope ytd-comment-renderer">
#               무지부부까리한데
#             </span>, <span class="style-scope ytd-comment-renderer">
#               JEREMY IVANDER
#             </span>, <span class="style-scope ytd-comment-renderer">
#               suneesh mohanan
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Bts love
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Mon Amoure
#             </span>, <span class="style-scope ytd-comment-renderer">
#               언니나다섯살이야
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Anut Tong
#             </span>, <span class="style-scope ytd-comment-renderer">
#               홍크Honk
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Himanshu Arya
#             </span>, <span class="style-scope ytd-comment-renderer">
#               MrRenegade2000
#             </span>, <span class="style-scope ytd-comment-renderer">
#               ki ko
#             </span>, <span class="style-scope ytd-comment-renderer">
#               ぴぴ。
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Kuroneko ASMR
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Mimi Shamimi
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Chika
#             </span>, <span class="style-scope ytd-comment-renderer">
#               s kl
#             </span>, <span class="style-scope ytd-comment-renderer">
#               minnu anu
#             </span>, <span class="style-scope ytd-comment-renderer">
#               ᄆᄆ
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Kdiebeu Cijdwhwu
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Lamar Thompson
#             </span>, <span class="style-scope ytd-comment-renderer">
#               가나다라
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Ling Ling
#             </span>, <span class="style-scope ytd-comment-renderer">
#               와구와구 오동동 WaguWagu O Dong-Dong
#             </span>, <span class="style-scope ytd-comment-renderer">
#               lude Inter
#             </span>, <span class="style-scope ytd-comment-renderer">
#               bunga angel jelita
#             </span>, <span class="style-scope ytd-comment-renderer">
#               조아라
#             </span>, <span class="style-scope ytd-comment-renderer">
#               ᄉᄒ
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Sharmishtha Sangamwar
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Xiaomi Redmi
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Erlinda Deguzman
#             </span>, <span class="style-scope ytd-comment-renderer">
#               불나방
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Cak Tomo
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Oculus boy 32
#             </span>, <span class="style-scope ytd-comment-renderer">
#               น้ำพริก พัชรินทร์
#             </span>, <span class="style-scope ytd-comment-renderer">
#               KOMERICAN
#             </span>, <span class="style-scope ytd-comment-renderer">
#               호박고구마
#             </span>, <span class="style-scope ytd-comment-renderer">
#               S. Hee
#             </span>, <span class="style-scope ytd-comment-renderer">
#               川崎美佳
#             </span>, <span class="style-scope ytd-comment-renderer">
#               JUNKIM ASMR
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Eat with Lina ASMR
#             </span>, <span class="style-scope ytd-comment-renderer">
#               smilegorgeous
#             </span>, <span class="style-scope ytd-comment-renderer">
#               감자
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Taekookies
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Hanzhelle Ebarola
#             </span>, <span class="style-scope ytd-comment-renderer">
#               가나다라
#             </span>, <span class="style-scope ytd-comment-renderer">
#               고래고래
#             </span>, <span class="style-scope ytd-comment-renderer">
#               모모쿠
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Lal Hmangaihzuali
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Just One More
#             </span>, <span class="style-scope ytd-comment-renderer">
#               이가
#             </span>, <span class="style-scope ytd-comment-renderer">
#               김예서
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Zahra Bhaiji
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Min yoongi Suga
#             </span>, <span class="style-scope ytd-comment-renderer">
#               cc
#             </span>, <span class="style-scope ytd-comment-renderer">
#               아임꿀복 갬성주부일상Daily life of baby
#             </span>, <span class="style-scope ytd-comment-renderer">
#               윤자몽
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Maira Alvarado
#             </span>, <span class="style-scope ytd-comment-renderer">
#               금순이
#             </span>, <span class="style-scope ytd-comment-renderer">
#               공실이
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Kaniz Fatema
#             </span>, <span class="style-scope ytd-comment-renderer">
#               슈슈
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Vegan Eats
#             </span>, <span class="style-scope ytd-comment-renderer">
#               -HK; SV,
#             </span>, <span class="style-scope ytd-comment-renderer">
#               이루지
#             </span>, <span class="style-scope ytd-comment-renderer">
#               언니나다섯살이야
#             </span>, <span class="style-scope ytd-comment-renderer">
#               첸첸
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Yari Yari
#             </span>, <span class="style-scope ytd-comment-renderer">
#               도신
#             </span>, <span class="style-scope ytd-comment-renderer">
#               케찹
#             </span>, <span class="style-scope ytd-comment-renderer">
#               언니나다섯살이야
#             </span>, <span class="style-scope ytd-comment-renderer">
#               윤은지
#             </span>, <span class="style-scope ytd-comment-renderer">
#               배추배
#             </span>, <span class="style-scope ytd-comment-renderer">
#               유말랭
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Mhmad Shboul123
#             </span>, <span class="style-scope ytd-comment-renderer">
#               John Brown
#             </span>, <span class="style-scope ytd-comment-renderer">
#               밍머
#             </span>, <span class="style-scope ytd-comment-renderer">
#               alishba tarakzai
#             </span>, <span class="style-scope ytd-comment-renderer">
#               임예슬
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Clariz Torres
#             </span>, <span class="style-scope ytd-comment-renderer">
#               정은희
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Salona
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Yssa Rabe
#             </span>, <span class="style-scope ytd-comment-renderer">
#               바다꽃
#             </span>, <span class="style-scope ytd-comment-renderer">
#               isrnice
#             </span>, <span class="style-scope ytd-comment-renderer">
#               언니나다섯살이야
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Hippo ASMR 입큰하마
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Fatma Nur Baranok
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Brooke Wilson
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Ulivi Shohe
#             </span>, <span class="style-scope ytd-comment-renderer">
#               동먹방
#             </span>, <span class="style-scope ytd-comment-renderer">
#               にょん
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Blanca Ramos
#             </span>, <span class="style-scope ytd-comment-renderer">
#               PaHoua Channel
#             </span>, <span class="style-scope ytd-comment-renderer">
#               김은비
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Himanshu Arya
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Shariq Ahmed
#             </span>, <span class="style-scope ytd-comment-renderer">
#               언니나다섯살이야
#             </span>, <span class="style-scope ytd-comment-renderer">
#               kim shoruq
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Tae K
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Sabina Sultanova
#             </span>, <span class="style-scope ytd-comment-renderer">
#               우비
#             </span>, <span class="style-scope ytd-comment-renderer">
#               sanu
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Nhi Lê
#             </span>, <span class="style-scope ytd-comment-renderer">
#               케로로
#             </span>, <span class="style-scope ytd-comment-renderer">
#               ゆい
#             </span>, <span class="style-scope ytd-comment-renderer">
#               ぴ!
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Shahroz Kabir
#             </span>, <span class="style-scope ytd-comment-renderer">
#               서희
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Jin Harem
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Shariq Ahmed
#             </span>, <span class="style-scope ytd-comment-renderer">
#               cow daddy
#             </span>, <span class="style-scope ytd-comment-renderer">
#               김혜림
#             </span>, <span class="style-scope ytd-comment-renderer">
#               rahaf amer
#             </span>, <span class="style-scope ytd-comment-renderer">
#               99瞳
#             </span>, <span class="style-scope ytd-comment-renderer">
#               ateezherseyim
#             </span>, <span class="style-scope ytd-comment-renderer">
#               マヨ
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Yumi
#             </span>, <span class="style-scope ytd-comment-renderer">
#               jUst 4 fUn
#             </span>, <span class="style-scope ytd-comment-renderer">
#               나는멋쟁이
#             </span>, <span class="style-scope ytd-comment-renderer">
#               이정현
#             </span>, <span class="style-scope ytd-comment-renderer">
#               PRINCESS CONSUELA
#             </span>, <span class="style-scope ytd-comment-renderer">
#               소정
#             </span>, <span class="style-scope ytd-comment-renderer">
#               허필립
#             </span>, <span class="style-scope ytd-comment-renderer">
#               장세령
#             </span>, <span class="style-scope ytd-comment-renderer">
#               kim lea
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Eliana Puha
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Ling Ling
#             </span>, <span class="style-scope ytd-comment-renderer">
#               머인마
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Marielle Castro
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Sarah-Leigh Theron
#             </span>, <span class="style-scope ytd-comment-renderer">
#               えんま大王
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Fiona Gildo
#             </span>, <span class="style-scope ytd-comment-renderer">
#               평범
#             </span>, <span class="style-scope ytd-comment-renderer">
#               모지
#             </span>, <span class="style-scope ytd-comment-renderer">
#               홍삼
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Shariq Ahmed
#             </span>, <span class="style-scope ytd-comment-renderer">
#               듀겅
#             </span>, <span class="style-scope ytd-comment-renderer">
#               장경수
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Marcus Bryan Mayor
#             </span>, <span class="style-scope ytd-comment-renderer">
#               심심shimshim
#             </span>, <span class="style-scope ytd-comment-renderer">
#               nana
#             </span>, <span class="style-scope ytd-comment-renderer">
#               엄기준
#             </span>, <span class="style-scope ytd-comment-renderer">
#               이정민
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Vony Marinda
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Lama vid
#             </span>, <span class="style-scope ytd-comment-renderer">
#               어어어어아어어어ᅥ
#             </span>, <span class="style-scope ytd-comment-renderer">
#               BLACK MØØD
#             </span>, <span class="style-scope ytd-comment-renderer">
#               [서이]TV
#             </span>, <span class="style-scope ytd-comment-renderer">
#               김씨
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Shannen Montaña
#             </span>, <span class="style-scope ytd-comment-renderer">
#               bee
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Natalina Silva
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Amreen Hussain
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Алаш Баласы
#             </span>, <span class="style-scope ytd-comment-renderer">
#               강슈크림
#             </span>, <span class="style-scope ytd-comment-renderer">
#               유유
#             </span>, <span class="style-scope ytd-comment-renderer">
#               홍도영
#             </span>, <span class="style-scope ytd-comment-renderer">
#               popo po
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Tarza
#             </span>, <span class="style-scope ytd-comment-renderer">
#               4B06鍾孟呈 CHUNG SARAH PARCO L.
#             </span>, <span class="style-scope ytd-comment-renderer">
#               설혜
#             </span>, <span class="style-scope ytd-comment-renderer">
#               민트맛탕
#             </span>, <span class="style-scope ytd-comment-renderer">
#               윤학수
#             </span>, <span class="style-scope ytd-comment-renderer">
#               stan ᴇɴʜʏᴘᴇɴ cause they r talented yikes
#             </span>, <span class="style-scope ytd-comment-renderer">
#               陶田泰代
#             </span>, <span class="style-scope ytd-comment-renderer">
#               ライライ
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Aica Hermoso
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Ling Ling
#             </span>, <span class="style-scope ytd-comment-renderer">
#               머리큰유노
#             </span>, <span class="style-scope ytd-comment-renderer">
#               차차ChaCha ASMR Shirtless상의탈의MUKBANG
#             </span>, <span class="style-scope ytd-comment-renderer">
#               핑후
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Rjean gomez
#             </span>, <span class="style-scope ytd-comment-renderer">
#               김수진
#             </span>, <span class="style-scope ytd-comment-renderer">
#               NINYBEE ASMR
#             </span>, <span class="style-scope ytd-comment-renderer">
#               감자
#             </span>, <span class="style-scope ytd-comment-renderer">
#               김소영
#             </span>, <span class="style-scope ytd-comment-renderer">
#               ARMY YUNA
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Marie Garcia
#             </span>, <span class="style-scope ytd-comment-renderer">
#               soknea khim
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Meraa hope
#             </span>, <span class="style-scope ytd-comment-renderer">
#               김뿌분
#             </span>, <span class="style-scope ytd-comment-renderer">
#               김석진김석진은 잘생겼습니다
#             </span>, <span class="style-scope ytd-comment-renderer">
#               민트초코쪼아!
#             </span>, <span class="style-scope ytd-comment-renderer">
#               셸림
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Roger Rogermore
#             </span>, <span class="style-scope ytd-comment-renderer">
#               권채은 Alice
#             </span>, <span class="style-scope ytd-comment-renderer">
#               김하윤
#             </span>, <span class="style-scope ytd-comment-renderer">
#               白咲まりん
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Kayla Germinal
#             </span>, <span class="style-scope ytd-comment-renderer">
#               포도
#             </span>, <span class="style-scope ytd-comment-renderer">
#               대프리카
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Loren Kikon
#             </span>, <span class="style-scope ytd-comment-renderer">
#               샌두의집 Sandu House
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Ynah Librea
#             </span>, <span class="style-scope ytd-comment-renderer">
#               neil baltazar
#             </span>, <span class="style-scope ytd-comment-renderer">
#               ARMY Raya Brnb Plms
#             </span>, <span class="style-scope ytd-comment-renderer">
#               TRISA KOLE
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Amanda G
#             </span>, <span class="style-scope ytd-comment-renderer">
#               깔꼼스
#             </span>, <span class="style-scope ytd-comment-renderer">
#               ㅎㅎㅎㅎㅎ
#             </span>, <span class="style-scope ytd-comment-renderer">
#               꾸리꾸리쿠카쿠카ᄏᄏᄏ
#             </span>, <span class="style-scope ytd-comment-renderer">
#               비아
#             </span>, <span class="style-scope ytd-comment-renderer">
#               만두만두만두
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Spandana
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Mariz esparcia
#             </span>, <span class="style-scope ytd-comment-renderer">
#               맨날 33에서틸트함
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Sela
#             </span>, <span class="style-scope ytd-comment-renderer">
#               An Phạm Đức
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Mari K
#             </span>, <span class="style-scope ytd-comment-renderer">
#               kane kim
#             </span>, <span class="style-scope ytd-comment-renderer">
#               ALIFA_SARA
#             </span>, <span class="style-scope ytd-comment-renderer">
#               dahyun _dubu
#             </span>, <span class="style-scope ytd-comment-renderer">
#               최정우
#             </span>, <span class="style-scope ytd-comment-renderer">
#               희원;
#             </span>, <span class="style-scope ytd-comment-renderer">
#               katana yoo
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Hakim Lee
#             </span>, <span class="style-scope ytd-comment-renderer">
#               즐거운유진
#             </span>, <span class="style-scope ytd-comment-renderer">
#               이구아나
#             </span>, <span class="style-scope ytd-comment-renderer">
#               여자친구 버디
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Sanfa Abdurahmaanfnf
#             </span>, <span class="style-scope ytd-comment-renderer">
#               우츠노미야시온이
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Genevieve Bogawit
#             </span>, <span class="style-scope ytd-comment-renderer">
#               Ryo Mon
#             </span>, <span class="style-scope ytd-comment-renderer">
# ...
# Hello boki
#               Shamyra Hodges
# BOKI! BOKI!I LUV YOU!!!!!!!!!!!!
#               Demie Jane Palayon
# 😋😋😋
#               Nymka Gombo
# i love you😘
#               ʀ ᴇ ᴀ ʟ ᴀ ᴄ ᴏ ʀ ᴛ ᴇ
# 😍😍😍😍😍
#               Gege cs
# Laper bukk mana lagi puasa
#               Lin da
# ❤💛💚💙💜
#               Caitlyn Lang
# MMMMMMMMMM
#               김쏘피
# 안보고싶은데  왜자꾸뜨나
#               Lizzy Woodhouse
# I had to google tendon because I kept thinking of anatomy...
#               Eru Saputra
# Wah temboloknya gede juga uhhh
#               Cicisri Mulyati
# ga ada tempe goreng yaa
#               Amar hijrat bin Abu samah
# 😘❤🥰😋😋😋😋
#               yaoi aliii
# ❤️
#               Jernielyn Jamolod
# iLoveyou Boki ❤️
#               Bona Spring
# Second😂😂😂
#               Shalini Shivakumar
# Wow boki kimchi💕🤩💕🤩💕
#               Z.S Eating show ASMR
# wow amazing video
#               Niles Gleichmann
# who else watching in ramadan
#               299리 루비
# 🥰🥰🥰🥰
#               Mhae Apacionado
# HIIIIIIIII
#               Boss J&D
# I love u boki
#               Ytrang_đây
# Mlem mlem
#               菜々
# 日本語でもテロップ入れてほしい🥺
#               스무스
# 오늘도 영상 켜자마자 한국인 찾기,,, 실패
#               Phương Nguyễn
# Hiiii
#               basma hasan
# Lav yoo
#               Thảo Trang TV
# Bt là lừa á nhưng vẫn coi
#               Chicken Man-치킨맨
# I'm chicken man. I'm uploading videos one by one, believing that I'll become a famous eating YouTuber like Boki. Thank you for being such a good example.😄😄😄
#               Dikshitha.R
# 1st comment u look so beautiful
#               Michelle Ann Buenaventura
# Bokiiiiiii!!!!!!
#               Masrevi Yuliandri
# Emgnya bener dia suka muntahin makanan ?
#               Mr Beast Channel
# So Delicous 🛀💋💘
#               Eat with Mohsin
# Why Does This Looks So delicious 😭😭 The Way You Eat!!!! So Tempting 😋🤩♥️
#               ted bear
# 😋
#               민지, 이릉
# 😚😚😚
#               Jui akter jui Jui
# Hi eaitng show asmr eating  beautiful waoo nice 🇧🇩 happy good day haaaaaaaaa 🇧🇩 Nice Nice Nice
#               moonlqghts
# Imagine getting heat from boki🙂
#               sidra dana
# I like you boki♥️ first mukbanger in the world 🌎
#               Chanyin 2009
# Boki❤
#               Urvi Hagavane
# Please try indian food ❤️❤️❤️
#               Iksan Firmansah
# ❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️
#               Boom 's
# Im french and I love your channel 🥰😂
#               its pani
# aku jadi lapar😭😭😭❤️❤️❤️
#               Salt&Pepper ASMR
# Who else wants to eat what Boki is eating? Me!!! 👇👇👇
#               Marami Marami
# I'm first✨
#               kageyana uwu
# So yummy Boki 😊🤎
#               Z
# love you boki
#               아니우다 aniuda
# 😀🤟😃
#               Belle Recalde
# I'M EARLY OMGGGG
#               Agatha zoey Zabala
# So satisfying
#               the science world
# Hi Boki iam your biggest fan
#               ROJBİN EĞE
# Merhaba❤️
#               Klhery
# Now I'm hungry ...
#               魚安安
# 안녕하세요. 저는 대만에서 왔고 여러분의 영상을 많이 봤습니다. 전에 가짜 음식을 먹었다 고해서 놀랐지 만 저 같은 진짜 사람이 있어도 정말 좋아해요. 당신과 나는 두 가지 특별한 비디오 클립을 확인해야합니다. 그것은 매우 어렵습니다. 난 그냥 열심히 영화를 만들 수 있도록 뭔가를 먹을 필요가 없다는 것을 말하고 싶다. 마찬가지로 나는 다음 날까지 식사를 마칠 수 없습니다,이 수도 하룻밤 음식을 좋아하지 않는 사람 수. 요점은 심지어 나와 함께, 나는 아직도 너무 많은 당신을 사랑한다는 것입니다. 나는 심각했다
#               angie lee
# Deep fried crispy u cooked or bought?
#               Global Foodie ASMR
# Yummmmmmmm
#               Ms Apple apple
# i love boki
#               dibyashree Bora
# Dont know about others but my Left ear hurts by the sound of pouring coke. But i love watching her😌
#               김동일
# 궁금해서 그런데 저렇게 많이먹고 위가 안좋다거나 하진 않으세요?걱정되는데
#               Adrian De Vera
# I love you so much
#               Raymond Sanjose
# Boki am a fan i need help i hope you read my comments 😊
#               皇.
# 和食だ〜！って思ったけどふりかけぶっかけてたりコーラ飲んでたり素手で食べてたりで、いろんな国の人に「これが天丼」って思われるのか？と思ったらちょっと残念かも。めっちゃいろんな種類あって美味しそうだけど！
#               quraisha
# Your face look like ryujin itzy..
#               Friendly Love
# Боки зачем так много кушать то)
#               Michelle Herrera
# Me gusta cuando comes pastel xd
#               Rithya Saji
# 👑 boki
#               MANAL HAZRAT MUHAMMAD
# Ahhhhhhh
#               ROJBİN EĞE
# Merhaba❤️❤️❤️
#               Margareta Margareta
# Hai mba boki saya suka makanan nya lop lop
#               sofiita
# hola algún comentario en español? JSKJSJS
#               정다운
# 누님 못 보던 사이에 살이 좀 찌셨넹
#               Aamina i guess
# Ouh early 😃
#               Ardina Febriana
# Second 🥈
#               뇌가있긴하냐?
# 몇주안본사이에 살좀찐거같네
#               강빈
# 0:53 start eating
#               wx_rosex
# Abla bir günde kebap yermisin.
#               Obito Uchiha
# Russian subtitles please!!!
#               Zana Ro
# Boki eating is the best
#               Ming Ben
# 坚决打击👊她的假吃，浪费食品，🈚️🈶️职业道德。
#               Ming Ben
# 坚决打击👊她的假吃，浪费食品，🈚️🈶️职业道德。
#               AXID YT
# bigfan
#               L3g1t
# 👽
#               — Peachy peach
# Help me I’m hungry 😣🤤
#               chellenging girls
# Biggest fan
#               chie s
# おいしそう🤤❤️
#               THUNDER SHADY
# Hii boki.... I really love your one shot mukbang your reactions are amazing ❤️❤️❤️❤️..... nd love you so much... Can you please on thier comment section..🙏🏼🙏🏼🙏🏼 I love your rections in one. Shot .. videos ....❤️❤️❤️
#               Maureen Grace Rabino
# Watching at 12 a.m. 😃😃😃
#               Reesha Zargar
# Amazing
#               tajana Tesan Tomic
# Hi i love you sooo much
#               공유찬
# 난이제 복희용서함 글고 넘맜있어보임 ㅋㅋㅎㅎ
#               Van Tai
# Ngon quá🇻🇳🇻🇳🇻🇳🇻🇳🇻🇳🇻🇳🇻🇳🇻🇳
#               Respect SuperhandsomeJungkook
# Jangan sampai ambil bukti lagi lagi ini haters
#               Oh me Art lover
# Can you eat Indian food next please..
#               Isak Permana
# Enak kali ya
#               Lê Mẫn
# .
#               Kaniz Fatema
# I'm a international fan of boki . Is you a international fan of boki
#               MHD GAMER
# Boki is my favourite
#               lola
# I am fasting 🤐
#               夏日れもん
# 日本で天丼にふりかけをかける文化はないから。他国の人達誤解しないで。
#               아뉜뒈에붸베베
# 항상 맛있게 드시고 항상 예쁘시고 음식 조합도 참 좋고 가리는 것 없이 다양한 음식 보여주시고 소리도 너무 너무 좋은데 당당하게 보기엔 아직 뭔가 좀 찜찜해...
#               Alexia
# Love u boki ❤️ wow amazing food darling
#               Elen Melkumyan
# i like u too much, but how u can eat too much and do not get fat)))) what is your secret?
#               AJ YT gamer
# First comment ❤️❤️❤️❤️
#               Ebrar Tuzgöllü
# Orucluyken bunu izliyorum çünkü ben bir malım
#               いえろーひまわり
# スプーンめっちゃ長いしでかい笑🥄韓国のってそうゆうものなのか
#               Crazy granny
# WOW! Girl, how is it U don't weigh 200 lbs ? I can just look at food and gain 5 lbs.🦊🦊🦊
#               Amor Lapas
# Her shirt was the same as last week ...
#               のはらしんのすけ
# 飲み込む時のカットが多すぎる…
#               ana toledo
# Se olvidaron de los subtítulos en Español 😖
#               dita foxx
# She’s a messy eater today lol
#               Edza Pangilinan
# I love watching you
#               Eman. Eletr206
# Do you really eat all of these huge amount as a meal in one day
#               милана Висханова
# О
#               Jui akter jui Jui
# খুব ভালো লাগছে ওয়াও আর নতুন কিছু open koro channel open koro sisters ooooooo 😀 nice 🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩🇧🇩😀
#               Nida Javed
# Woo~ I'm the first 😝
#               Rina Sirak
# boki
#               greysell Gómez
# Alguien en Español 🤭
#               le wolf
# Big bites : I am i jock to you
#               Vungsonkim Tangpua
# Your the best
#               Jui akter jui Jui
# Nice nice Nice
#               LOLOSAN099 unu
# هاثولحعاثث
#               7 •Ami
# Your interpretation is the same as that of Vietnam
#               김건영
# 아니 삼키는거쫌 보여봐 삼킬때만 편집 ㅆ 오지네
#               Crafty Confections
# My kids love to watch you eat!
#               wo0bear _
# omg tendon is one of my favourites!
#               Oli G
# i dont know if frying enoki mushrooms is good idea i mean theyre so soft and batter killing their taste😆
#               chellenging girls
# Who like boki video
#               Angelica Solomon
# Titan's mouth 😅
#               みんゆん
# 日本来て欲しい
#               pardon?
# WHO LOVES BOKI? ❤️
#               aldana
# boki i love you u know
#               aung zaw
# Ramadan
#               あなたのオレオとります
# I love you Boki
#               อานิสา โพธิโรจน์ 41
# sub thai :'(
#               Jaezel Parrera
# I'm so early
#               Hara Lee
# Hi Boki's fans👇
#               Sahar Adiban
# Hi,I'm Iranian
#               ASHLEY VENCITO
# Wow!!!
#               Lily Cl
# So cool
#               Hanna Sabado
# Hi boki.
#               Asllie Nicdao
# hi bokii
#               Mj Manansala
# boki wants to laugh😭😭
#               Raz Raz
# Omg🥺🙃
#               Naz Koca
# Ok guys I'm hungry
#               Yareilis Santiago-Campos
# for some reason there should be a boki cult...just saying...
#               Jisoo Is jisoo
# Second and hi
#               Sonia Briceñp
# Será verdad que le cabe tanta comida
#               Nadhifa Aqma
# 1 minutes ago😜
#               えり
# どんどん大食いになってる？
#               Chen Fei
# I love u
#               井上かおり
# うどんが辛そう
#               ورده الانباري
# Hello😊😊😊
#               Denise Kün
# Hi!
#               Rohini
# 50 percent coke 50 percent water
#               экспериментный канал
# I love you
#               Тимур Джураев
# I love you
#               Тимур Джураев
# I love you
#               เม วิลา
# Thai translate please
#               ゆさん
# ご飯粒めっちゃ残してて不快でした
#               Lidelet Bonifacio
# Gooooooooooooooood
#               basma hasan
# good
#               lolipuffs
# earlyyy!!
#               DREW YT CHANNEL
# I cant comment in your video but i can comment here 😀
#               こなSUN
# 天丼だ
#               Charlotte Queen
# Yum!
#               Mahendra Pratap Singh
# Ma'am try india food
#               ささふな
# さくさくだけど手作り？
#               Astha arobi
# you will must try Indian food
#               Blanca Ramos
# Me encantan tus videos
#               fiyyna
# 19minutes ago...😩
#               Umme Aiman
# What is the fried food platter called?
#               Vera Nvchks
# quer empilhar um monte de comida pra poder encher a boca que ela acaba caindo,,não te preocupa que a comida não vai fugir.
#               L f
# Love tempura.  The fish and veggies all look greasy.
#               Frau Chen
# Omg one day you’ll get gerd. I’ve just recently been diagnosed with gerd cause my favourite thing in the world is fried and SPICY food. Please eat moderately
#               Poonam Parashar
# Please you will try indian food
#               Dıljin Bilge
# Hi.
#               Nicolas br
# Te amo
#               ธวัลรัตน์ ธงชัย
# I like to watching you
#               Vậy Người ta
# Why are you not fat ? 😅😅😅
#               samaya hall
# this early
#               ぬぬ
# 天丼、どんぶりの大きさと天ぷらの多さでデカ盛りか？と思ったけど、ご飯の量はそんなんでもないのかな？
#               다원
# 왜 여기는 라방을 안하나요?
#               Wang Yirenie
# Takoyaki pls
#               Kui Mohnyuk
# Early!!
#               Emblerla
# How many international Boki fans 👇Love you Boki 😊💛
#               Ahhlexx Benitez
# Earlyyy
#               prutha Vakharia
# Please please please please please please try indian food please
#               Angelyn Suarez
# Hi boki
#               Kris Anne Piaje
# Hi boki
#               fly
# 13 s ago
#               Надюшкина Жизнь
# Не дури людей
#               AnyaFlowers! Sushi :3
# hi
#               Good family
# 1 comment💬
#               AJ YT gamer
# Hi
#               chanelt sanchez
# 🤢🤢🤢🤢🤢🤢
#               FAI WATCHARAPORN
# HI
#               AJ YT gamer
# Please say hi
#               a n
# ごはん粒の残し方がいつもより汚いな？！？！
#               Aryan Singh
# Pin this comment, I am from INDIA 😊
#               Ghulam Abbas
# Whenever you again uploade the  same video then comments are turned off !!! 🙄🙄 what's the problem ????
#               Brittany Mendez
# Second
#               Michaela abarico
# Hi
#               Cassandra Nicole Tunay
# i liked the moment you droped your food
#               porjailovely chanel
# Ninth
#               ゆづき
# ふりかけのかけ方雑すぎる食べ物を粗末に扱い不快もっと大切に食べてほしい
#               Tika Mamy
# É magra de ruim viu...😳
#               gpdlffl qkr
# 긍데 무편집본이면 편집이 필요없는데 왜 한꺼번에 못올리는거임..?
#               김석진김석진은 잘생겼습니다
# BOKKIII HIII
#               シꨄ ᴍᴇʟᴏᴅʏ ꨄシ
# e
#               Khaled alwadaani
# First
#               Sabrina Mounts
# don't listen to the haters. you're literally the queen
#               Lucia Blanco
# 🤮🤮🤮
#               Nansbbgrand
# I must tell you, Boki, I really don't like you new videos on  alternate days, where it's (Not ASMR), and you're not texting anything to us, and connecting with us like you always have. But fixing your lipstick, and things, primping in the mirror, behind the camera, I guess. I like it much better when you're just, as if, dining right along with us, enjoying your yummy meals, letting us know how it tastes.. acting like you're at the dining table with us. You wouldn't fix your makeup, and worry about your appearance at the dinner table, would you? Please.. Go back to being fun, and fantastic feasting on your FOOD! LOVE you, Boki! xoxo
#               용사
# 다 뱉을거면서 아직도 방송하네 에휴ㅉㅉ
#               mooo mu
# これを天丼と言わないでほしい。全くの別物。揚げ物丼だろこれ
#               ItzNala!
# HII can u please ping me
#               Sharon Begum
# Not you again fulling the public Boki
#               Alien X
# Mó Fome
#               ka zu
# キムチうどん、ほとんどスープだけじゃん。天孫のご飯も普通の約一膳分だし。器だけ大きくして大食いに見せかけてるだけじゃん。炎上前はもーっと食べてましたよね？　あ、あの量は巧妙な「カット」ありきでしたもんねー。
#               Katherine A
# Not a judge, but prefer not to have 'haa' sound after each drinking,  it ruins the whole asmr
#               Theresia LHP
# the point is just enjoy the food by eating it properlyYou don't need to make an attraction that isn't funny but makes you look silly with your eating styleooohh my GOD......it's not funny but it's ridiculous hihihi
#               Sultana E Monjerina
# Why u just edit at the moment of swallowing?? U chew all the foods  but when  its time to swallow i found u to take the next spoon..just only liquid foods u drink. why? Is it only me or anybody else?
#               zippo1213
# 먹다 토할거면 쳐먹지 마세요 ㅡㅡ
#               小熊
# 🤮

# %%
print(soup)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
print(soup)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# !pip update numpy

# %%
import pandas as pd

# %%
from selenium import webdriver as wd
from bs4 import BeautifulSoup
import time
import pandas as pd
import requests
import re

def get_urls_from_youtube_with_keyword(keyword):
    titles = []
    urls = []
    
    search_keyword_encode = requests.utils.quote(keyword)
    
    url = "https://www.youtube.com/results?search_query=" + search_keyword_encode
    
    driver = wd.Chrome(executable_path="chromedriver.exe")
    
    driver.get(url)
    
    last_page_height = driver.execute_script("return document.documentElement.scrollHeight")

    while True:
        driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
        
        time.sleep(3.0)
        
        
        new_page_height = driver.execute_script("return document.documentElement.scrollHeight")
        
        if new_page_height == last_page_height:
            break
            
        last_page_height = new_page_height
        
    html_source = driver.page_source
    
    driver.quit()
    
    soup = BeautifulSoup(html_source, 'lxml')
    
    datas = soup.select("a#video-title")

    for data in datas:
        title = data.text.replace('\n', '')
        url = "https://www.youtube.com/" + data.get('href')
        
        titles.append(title)
        urls.append(url)
        
    return titles, urls

def crawl_youtube_page_html_sources(urls):
    html_sources = []

    for i in range(len(urls)):
        driver = wd.Chrome(executable_path="chromedriver.exe")
        driver.get(urls[i])

        last_page_height = driver.execute_script("return document.documentElement.scrollHeight")

        while True:
            driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
            time.sleep(3.0)
            new_page_height = driver.execute_script("return document.documentElement.scrollHeight")

            if new_page_height == last_page_height:
                break
            last_page_height = new_page_height


        html_source = driver.page_source
        html_sources.append(html_source)
        print("OK")

        driver.quit()
    return html_sources

def get_user_IDs_and_comments(html_sources):
    my_dataframes = []
    for html in html_sources:
        
        soup = BeautifulSoup(html, 'lxml')
        
        youtube_user_IDs = soup.select('div#header-author > a > span')

        youtube_comments = soup.select('yt-formatted-string#content-text')
        
        str_youtube_userIDs = []
        str_youtube_comments = []

        for i in range(len(youtube_user_IDs)):
            str_tmp = str(youtube_user_IDs[i].text)
        #     print(str_tmp)
            str_tmp = str_tmp.replace('\n', '')
            str_tmp = str_tmp.replace('\t', '')
            str_tmp = str_tmp.replace('                ','')
            str_youtube_userIDs.append(str_tmp)

            str_tmp = str(youtube_comments[i].text) 
            str_tmp = str_tmp.replace('\n', '')
            str_tmp = str_tmp.replace('\t', '')
            str_tmp = str_tmp.replace('               ', '')

            str_youtube_comments.append(str_tmp)
            
        pd_data = {"ID":str_youtube_userIDs, "Comment":str_youtube_comments}

        youtube_pd = pd.DataFrame(pd_data)

        my_dataframes.append(youtube_pd)
        
    return my_dataframes

def convert_csv_from_dataframe(titles, my_dataframes):
    for i in range(len(my_dataframes)):
        title = re.sub('[-=+,#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…《\》]', '', titles[i])
        my_dataframes[i].to_csv("{}.csv".format(title))

# %%
titles, urls = get_urls_from_youtube_with_keyword("랄로")

html_sorces = crawl_youtube_page_html_sources(urls)

my_dataframes = get_user_IDs_and_comments(html_sorces)

convert_csv_from_dataframe(titles, my_dataframes)
# Out:
# OK
# OK
# OK
# OK
# OK
